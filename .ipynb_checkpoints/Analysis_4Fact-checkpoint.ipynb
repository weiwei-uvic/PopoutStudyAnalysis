# %% [markdown]
# # Bayesian Model for 4 Nominal Predictors (Feature, Element number, Spatial pattern, Target location)

# %% [markdown]
# ## 1). Preparation

# %% [markdown]
# ### 1.1). Load required libaraies

# %%
#install.packages("png")

# %%
#Libs and File-wide Constants
library(rjags)
library(runjags)
library(ggplot2)
library(gridExtra)
library(reshape2)
library(dplyr)
library(binr)
library(readr)
library(jsonlite)
library(LaplacesDemon)
library(mosaicCore)
testjags()
# Out:
# You are using R version 4.1.3 (2022-03-10) on a windows machine, with
# the RTerm GUI
# JAGS version 4.3.0 found successfully using the command
# 'C:/Programs/JAGS/x64/bin/jags-terminal.exe'
# The rjags package is installed

# %% [markdown]
# ### 1.2). Define constants

# %%
features = c("Hue","Length","Shape")
elementNums = c("12","48", "192","768")
spatialPatterns = c("Gridded","Random")
centerOrPeriph = c("Center","Periphery")
columns_to_keep = c('PID','ReactionTime','ReactionTimeLog','Feature','ElemNum','SpatialPattern','CenterOrPeriph','Target2CenterDis')

# Specify the column names in the data file relevant to the analysis:
yName="ReactionTimeLog" 
# yName="durationLog"
# x1 should be factor with fewer levels, to plot in single pane:
x1Name="SpatialPattern" 
x2Name="CenterOrPeriph"
x3Name="Feature"
x4Name="ElemNum"
# Task analysis constants
# current_task=2
# current_task_short_name= all_tasks_short_names[[current_task]]
# current_analysis_name ="Main"
# current_task_name = all_tasks[[current_task]]
# cat("Active task under analysis:",current_task_name,"(",current_task,")")

displayParameters = c( "b0", "b1[1]", "b1[2]", "b2[1]" ,"b2[2]", "b3[1]" ,"b3[2]", "b3[3]" ,"b4[1]" ,"b4[2]" ,"b4[3]" ,"b4[4]"
                                  #, "a1SD" , "a2SD" , "a1a2SD" ,"sigmaMode" , "sigmaSD" , "nu"
                                 )
displayAltParNames = c("intercept", "Gridded","Random","Center","Periphery","Hue","Length","Shape","12","48", "192","768"
                                   #, "a1SD" , "a2SD" , "a1a2SD" ,"sigmaMode" , "sigmaSD" , "nu" 
                                  )


# Path constants
mcmcDir = "calculatedMCMCs/"
resultsDir = "results/"
resultsGraphicsDir = "graphicResults/"

# %% [markdown]
# ### 1.3). Include plot functions from Kruschke and Miguel

# %%
# Functions adapted from Kruchke's code

DbdaAcfPlot = function( codaObject , parName=varnames(codaObject)[1] , plColors=NULL ) 
{
  if ( all( parName != varnames(codaObject) ) ) { 
    stop("parName must be a column name of coda object")
  }
  nChain = length(codaObject)
  if ( is.null(plColors) ) plColors=1:nChain
  xMat = NULL
  yMat = NULL
  for ( cIdx in 1:nChain ) {
    acfInfo = acf(codaObject[,c(parName)][[cIdx]],plot=FALSE) 
    xMat = cbind(xMat,acfInfo$lag)
    yMat = cbind(yMat,acfInfo$acf)
  }
  matplot( xMat , yMat , type="o" , pch=20 , col=plColors , ylim=c(0,1) ,
           main="" , xlab="Lag" , ylab="Autocorrelation" )
  abline(h=0,lty="dashed")
  EffChnLngth = effectiveSize(codaObject[,c(parName)])
  text( x=max(xMat) , y=max(yMat) , adj=c(1.0,1.0) , cex=1.25 ,
        labels=paste("ESS =",round(EffChnLngth,1)) )
}

DbdaDensPlot = function( codaObject , parName=varnames(codaObject)[1] , plColors=NULL ) {
  if ( all( parName != varnames(codaObject) ) ) { 
    stop("parName must be a column name of coda object")
  }
  nChain = length(codaObject) # or nchain(codaObject)
  if ( is.null(plColors) ) plColors=1:nChain
  xMat = NULL
  yMat = NULL
  hdiLims = NULL
  for ( cIdx in 1:nChain ) {
    densInfo = density(codaObject[,c(parName)][[cIdx]]) 
    xMat = cbind(xMat,densInfo$x)
    yMat = cbind(yMat,densInfo$y)
    hdiLims = cbind(hdiLims,HDIofMCMC(codaObject[,c(parName)][[cIdx]]))
  }
  matplot( xMat , yMat , type="l" , col=plColors , 
           main="" , xlab="Param. Value" , ylab="Density" )
  abline(h=0)
  points( hdiLims[1,] , rep(0,nChain) , col=plColors , pch="|" )
  points( hdiLims[2,] , rep(0,nChain) , col=plColors , pch="|" )
  text( mean(hdiLims) , 0 , "95% HDI" , adj=c(0.5,-0.2) )
  EffChnLngth = effectiveSize(codaObject[,c(parName)])
  MCSE = sd(as.matrix(codaObject[,c(parName)]))/sqrt(EffChnLngth) 
  text( max(xMat) , max(yMat) , adj=c(1.0,1.0) , cex=1.25 ,
        paste("MCSE =\n",signif(MCSE,3)) )
}
    
HDIofMCMC = function( sampleVec , credMass=0.95 ) {
  # Computes highest density interval from a sample of representative values,
  #   estimated as shortest credible interval.
  # Arguments:
  #   sampleVec
  #     is a vector of representative values from a probability distribution.
  #   credMass
  #     is a scalar between 0 and 1, indicating the mass within the credible
  #     interval that is to be estimated.
  # Value:
  #   HDIlim is a vector containing the limits of the HDI
  sortedPts = sort( sampleVec )
  ciIdxInc = ceiling( credMass * length( sortedPts ) )
  nCIs = length( sortedPts ) - ciIdxInc
  ciWidth = rep( 0 , nCIs )
  for ( i in 1:nCIs ) {
    ciWidth[ i ] = sortedPts[ i + ciIdxInc ] - sortedPts[ i ]
  }
  HDImin = sortedPts[ which.min( ciWidth ) ]
  HDImax = sortedPts[ which.min( ciWidth ) + ciIdxInc ]
  HDIlim = c( HDImin , HDImax )
  return( HDIlim )
}

diagMCMC = function( codaObject , parName=varnames(codaObject)[1] ,
                     saveName=NULL , saveType="jpg", parAltName=NULL ) {
# Note: original version by Kruchke
    
  if (is.null(parAltName)) {
      parAltName = parName
  }
  DBDAplColors = c("red","green","blue","cyan","magenta","yellow","black","purple")
  # openGraph(height=5,width=7)
  par( mar=0.5+c(3,4,1,0) , oma=0.1+c(0,0,2,0) , mgp=c(2.25,0.7,0) , 
       cex.lab=1.5 )
  layout(matrix(1:4,nrow=2))
  # traceplot and gelman.plot are from CODA package:
  require(coda)
  verticalAxisName = paste("Param. Value of ",parAltName,"")
  coda::traceplot( codaObject[,c(parName)] , main="" , ylab="Param. Value" ,
                   col=DBDAplColors ) 
  tryVal = try(
    coda::gelman.plot( codaObject[,c(parName)] , main="" , auto.layout=FALSE , 
                       col=DBDAplColors )
  )  
  # if it runs, gelman.plot returns a list with finite shrink values:
  if ( class(tryVal)=="try-error" ) {
    plot.new() 
    print(paste0("Warning: coda::gelman.plot fails for ",parName))
  } else { 
    if ( class(tryVal)=="list" & !is.finite(tryVal$shrink[1]) ) {
      plot.new() 
      print(paste0("Warning: coda::gelman.plot fails for ",parName))
    }
  }
  DbdaAcfPlot(codaObject,parName,plColors=DBDAplColors)
  DbdaDensPlot(codaObject,parName,plColors=DBDAplColors)
  mtext( text=parAltName , outer=TRUE , adj=c(0.5,0.5) , cex=2.0 )
}


calcAndPlotContrasts = function(coda,dataFrame,x1Name, rootName = "b1") {
  x1levels = levels(as.factor(dataFrame[,x1Name])) 
  str(x1levels)
  matData = as.matrix(coda,chains=TRUE)    
  numericOutput = list()  
    
  for (i in 1:length(x1levels)) {
      nameCol = x1levels[i]
      numericOutput[[nameCol]] = list()
      
      for (j in 1:length(x1levels)) {
          nameRow = x1levels[j]
          
          # print(paste("i,j:",nameCol,nameRow))
          title = paste(nameCol,"-",nameRow)
          if (j>i) {
               numericOutput[[nameCol]][[nameRow]] = plotAndCalcDifference(matData=matData,i=i,j=j,title=title, varRootName = rootName)
              
          }          
      }
  }
  return(numericOutput)    
}

plotAndCalcDifference = function(matData,i,j,title,varRootName = "b1",verbose = TRUE) {
    
    output = list()
    
    varName1 = paste(varRootName,"[",i,"]",sep="")
    varName2 = paste(varRootName,"[",j,"]",sep="")      
    myDiff = matData[,varName1] - matData[,varName2]
    plotPost(myDiff,main=title)
    
    # calculated variables
    probVar1Larger = mean(as.numeric(myDiff>0))
    
    output["probVar1Larger"] = probVar1Larger
    
    if (verbose) {
        print(paste(title,"probVar1Larger:",probVar1Larger))
    }
    
    return(output)
}

# %% [markdown]
# ### 1.4). Define the runMCMC function that run MCMC model, return a coda

# %%
runMCMC = function(data,
                          modelString,parameters,parNames,
                          numSavedSteps=50000, thinSteps=1, 
                          nChains = 8,
                          testName="no-name",
                          mcmcDir = mcmcDir,
                          loadExistingFiles = TRUE,
                          saveCalculatedFiles = TRUE,
                          resultsDir = resultsDir,
                          # showDiag=TRUE,
                          # saveDiag=TRUE,
                          # showPostGraphs = TRUE,
                          # savePostGraphs = TRUE,
                          # showNumericResults = TRUE,
                          # saveNumericResults = TRUE,
                          silent = FALSE
                         ) 
{
    
    fileNameRJO = paste(mcmcDir,testName,"-",numSavedSteps*thinSteps,".rjr",sep="")
    fileNameCoda = paste(mcmcDir,testName,"-",numSavedSteps*thinSteps,".coda",sep="")
    fileNameData = paste(mcmcDir,testName,"-",numSavedSteps*thinSteps,".data",sep="")
    
    rjo=NULL
    coda=NULL
    dataIn = NULL
    
    numeric_results = list()
    
    computeNewMCMC = TRUE
    
    # Check if existing files for this run exist
    if (loadExistingFiles) 
    {
        if(file.exists(fileNameRJO) && file.exists(fileNameCoda) && file.exists(fileNameData)) 
        { 
            rjo = readRDS(fileNameRJO)
            print(paste("RJO file found and loaded: ",fileNameRJO))
            coda = readRDS(fileNameCoda)
            print(paste("Coda file found and loaded: ",fileNameCoda))
            dataIn = readRDS(fileNameData)
            print(paste("Data file found and loaded: ",fileNameData))
            
            computeNewMCMC = FALSE
            
        } 
        else 
            dataIn = data
    }
    
    if(computeNewMCMC) 
    {
        writeLines(modelString,con="TEMPmodel.txt")
        adaptSteps = 1000 
        burnInSteps = 2000 
        # run.jags is a method provided by runjags, which supports to run parallel chains in JAGS
        rjo <- run.jags( method="parallel" ,
                          model="TEMPmodel.txt" , 
                          monitor=parameters , 
                          data=dataIn ,  
                          #inits=initsList , 
                          n.chains=nChains ,
                          adapt=adaptSteps ,
                          burnin=burnInSteps , 
                          sample=ceiling(numSavedSteps/nChains) , # specify the number of steps
                          thin=thinSteps ,
                          summarise=TRUE , # whether or not to compute diagnostic statistics for every parameter.
                          modules ="glm",
                          silent.jags = silent,
                          plots=FALSE )
        coda = as.mcmc.list( rjo )
        
        saveRDS(rjo,fileNameRJO)
        saveRDS(coda,fileNameCoda)
        saveRDS(dataIn,fileNameData)
    }  
    return(coda)
}

# %% [markdown]
# ### 1.5) Define the plotMCMC function that plots coda results

# %%
plotMCMC = function( codaSamples , 
                     datFrm , yName="y" , spatialPattern = "Gridded", targetLocation = "Center", x1Name="x1" , x2Name="x2" ,
                     saveName=NULL , saveType="jpg" ) 
{
  mcmcMat = as.matrix(codaSamples,chains=TRUE)
  chainLength = NROW( mcmcMat )
  y = datFrm[,yName]
  x1 = as.numeric(as.factor(datFrm[,x1Name]))
  x1levels = levels(as.factor(datFrm[,x1Name]))
  x2 = as.numeric(as.factor(datFrm[,x2Name]))
  x2levels = levels(as.factor(datFrm[,x2Name]))

  # get the index of spatialPattern and TargetLocation
  spIdx = which(spatialPatterns == spatialPattern) # spatial pattern
  tlIdx = which(spatialPatterns == spatialPattern) # target location
  # Display data with posterior predictive distributions
  for ( x2idx in 1:length(x2levels) ) {
    #openGraph(width=1.2*length(x1levels),height=5)
    par( mar=c(4,4,2,1) , mgp=c(3,1,0) )
    plot(-10,-10, 
         xlim=c(0.2,length(x1levels)+0.1) , 
         xlab=paste(x1Name,x2Name,sep="\n") , 
         xaxt="n" , ylab=yName ,
         ylim=c(min(y)-0.2*(max(y)-min(y)),max(y)+0.2*(max(y)-min(y))) ,
         main="Data with Post. Pred.")
    axis( 1 , at=1:length(x1levels) , tick=FALSE ,
          lab=paste( x1levels , x2levels[x2idx] , sep="\n" ) )
    for ( x1idx in 1:length(x1levels) ) {
      xPlotVal = x1idx #+ (x2idx-1)*length(x1levels)
      yVals = y[ x1==x1idx & x2==x2idx ]
      points( rep(xPlotVal,length(yVals))+runif(length(yVals),-0.05,0.05) , 
              yVals , pch=1 , cex=1.5 , col="red" )
      chainSub = round(seq(1,chainLength,length=20))
      for ( chnIdx in chainSub ) {
        m = mcmcMat[chnIdx,paste0("m[",spIdx,",",tlIdx,",",x2idx,",",x1idx,"]")]
        s = mcmcMat[chnIdx,paste0("ySigma[",spIdx,",",tlIdx,",",x2idx,",",x1idx,"]")]
        n = mcmcMat[chnIdx,"nu"]

        tlim = qt( c(0.025,0.975) , df=n )
        yl = m+tlim[1]*s
        yh = m+tlim[2]*s
        ycomb=seq(yl,yh,length=201)
        yt = dt( (ycomb-m)/s , df=n )
        yt = 0.67*yt/max(yt)
        lines( xPlotVal-yt , ycomb , col="skyblue" ) 
        
      }
    }
    if ( !is.null(saveName) ) {
      saveGraph( file=paste0(saveName,"PostPred-",x2levels[x2idx]), type=saveType)
    }
  } # end for x2idx

  # Display the normality and top-level variance parameters:
  #openGraph(width=8,height=3)
  layout( matrix(1:3,nrow=1) )
  par( mar=c(4,4,2,1) , mgp=c(3,1,0) )
  compInfo = plotPost( log10(mcmcMat[,"nu"]) , xlab=expression("log10("*nu*")") ,
                       main="Normality", compVal=NULL , ROPE=NULL )
  compInfo = plotPost( mcmcMat[,"sigmaMode"] , xlab="param. value" ,
                       main="Mode of Cell Sigma's", compVal=NULL , ROPE=NULL )
  compInfo = plotPost( mcmcMat[,"sigmaSD"] , xlab="param. value" ,
                       main="SD of Cell Sigma's", compVal=NULL , ROPE=NULL )
  if ( !is.null(saveName) ) {
    saveGraph( file=paste0(saveName,"NuSigmaMode"), type=saveType)
  }
}


plotInteractionContrast = function(codaSamples , datFrm, x1x2contrasts=NULL)
{
  mcmcMat = as.matrix(codaSamples,chains=TRUE)
  # interaction contrasts:
  if ( !is.null(x1x2contrasts) ) {
    for ( cIdx in 1:length(x1x2contrasts) ) {
      thisContrast = x1x2contrasts[[cIdx]]
      # factor A contrast:
      facAcontrast = thisContrast[[1]]
      facAcontrastLeft = facAcontrast[[1]]
      facAcontrastRight = facAcontrast[[2]]
      left = right = rep(FALSE,length(x1levels))
      for ( nIdx in 1:length( facAcontrastLeft ) ) { 
        left = left | x1levels==facAcontrastLeft[nIdx]
      }
      left = normalize(left)
      for ( nIdx in 1:length( facAcontrastRight ) ) { 
        right = right | x1levels==facAcontrastRight[nIdx]
      }
      right = normalize(right)
      facAcontrastCoef = left-right
      # factor B contrast:
      facBcontrast = thisContrast[[2]]
      facBcontrastLeft = facBcontrast[[1]]
      facBcontrastRight = facBcontrast[[2]]
      left = right = rep(FALSE,length(x2levels))
      for ( nIdx in 1:length( facBcontrastLeft ) ) { 
        left = left | x2levels==facBcontrastLeft[nIdx]
      }
      left = normalize(left)
      for ( nIdx in 1:length( facBcontrastRight ) ) { 
        right = right | x2levels==facBcontrastRight[nIdx]
      }
      right = normalize(right)
      facBcontrastCoef = left-right
      # interaction contrast:
      contrastCoef = cbind( as.vector( 
        outer( facAcontrastCoef , facBcontrastCoef ) ) )
      postContrast = ( mcmcMat[,substr(colnames(mcmcMat),1,5)=="b1b2b3b4["] 
                       %*% contrastCoef )
      mainName = paste0(
        paste0(paste(thisContrast[[1]][[1]],collapse="."), 
               ".v.",
               paste(thisContrast[[1]][[2]],collapse=".")),
        "\n(x)\n",
        paste0(paste(thisContrast[[2]][[1]],collapse="."), 
               ".v.",
               paste(thisContrast[[2]][[2]],collapse=".")))
      #openGraph(height=4,width=4)
      compInfo = plotPost( postContrast , xlab="Difference of Differences" ,
                           main=mainName ,
                           compVal=thisContrast$compVal ,
                           ROPE=thisContrast$ROPE )
      fileNameSuffix = paste0(
        paste0(paste(thisContrast[[1]][[1]],collapse="."), 
               ".v.",
               paste(thisContrast[[1]][[2]],collapse=".")),
        "(x)",
        paste0(paste(thisContrast[[2]][[1]],collapse="."), 
               ".v.",
               paste(thisContrast[[2]][[2]],collapse=".")))
      # saveGraph(file=paste0(saveName,fileNameSuffix),
      #           type=graphFileType)
    }
  } # end of interaction contrasts
}

# %% [markdown]
# ## 2). Load data

# %%
folder = "data/"
files = list.files(path = folder, pattern="*\\.csv$")

allDFList = list()

for (myFile in files) {
  myDF = read.csv(file = paste(folder,myFile,sep=""),sep=",", na.strings = c("null"))
  myDF <- subset(myDF, !is.na(ReactionTime))
  myDF$ElemNum <- factor(myDF$ElemNum)    ## Convert the 'ElemNum' column to a factor (nominal)
  myDF$Feature <- factor(myDF$Feature)
  myDF$SpatialPattern <- factor(myDF$SpatialPattern)
  myDF$CenterOrPeriph <- factor(myDF$CenterOrPeriph)
  allDFList[[length(allDFList)+1]]=myDF
}
df = do.call("rbind",allDFList)

df = df[columns_to_keep]
head(df)
# Out:
#   PID ReactionTime ReactionTimeLog Feature ElemNum SpatialPattern
# 1 3    1507.0      3.178113        Shape   768     Random
# 2 3    7632.6      3.882673        Shape   768     Random
# 3 3   23285.2      4.367080        Shape   768     Random
# 4 3   33382.0      4.523512        Shape   768     Random
# 5 3    7686.5      3.885729        Shape   768     Random
# 6 3    5805.3      3.763825        Shape   768     Random
#   CenterOrPeriph Target2CenterDis
# 1 Center         0.1064987
# 2 Center         0.2290965
# 3 Center         0.1701157
# 4 Periphery      0.6543107
# 5 Center         0.2362122
# 6 Periphery      0.2963505

# %% [markdown]
# ## 3). Define the model and get all needed information

# %% [markdown]
# ###  3.1) Model of four factors with interaction for ReactionTimeLog

# %%
fourFactsModel = "
  model {
    for ( i in 1:Ntotal ) {
      y[i] ~ dt( mu[i] , 1/(ySigma[x1[i],x2[i],x3[i],x4[i]])^2, nu ) # likehood
      mu[i] <- a0 + a1[x1[i]] + a2[x2[i]] + a3[x3[i]] + a4[x4[i]] + a1a2a3a4[x1[i],x2[i],x3[i],x4[i]]
    }
    # For sparse data with lots of outliers, there can be multimodal small-nu
    # estimates, in which case you may want to change the prior to force a 
    # larger value of nu, such as  nu ~ dgamma(5.83,0.0483)  mode 100, sd 50


    ### Priori definitions
    # priori for nu
    # nu: the “normality” parameter, range from 1 to infinite.
    nu ~ dexp(1/30.0)  #This line equals to:  nu <- nuMinusOne+1 and nuMinusOne ˜ dexp(1/29)
    #
    # priori for sigma
    for ( j1 in 1:Nx1Lvl ) {
            for ( j2 in 1:Nx2Lvl ) { 
                 for ( j3 in 1:Nx3Lvl ) { 
                          for ( j4 in 1:Nx4Lvl ) { 
                                 sigma[j1,j2,j3,j4] ~ dgamma( sigmaSh , sigmaRa )
                                 ySigma[j1,j2,j3,j4] <- max( sigma[j1,j2,j3,j4] , medianCellSD/1000 )
               }
           }
        }
     }
    sigmaSh <- 1 + sigmaMode * sigmaRa
    sigmaRa <- ( sigmaMode + sqrt( sigmaMode^2 + 4*sigmaSD^2 ) ) /(2*sigmaSD^2)
    sigmaMode ~ dgamma(sGammaShRa[1],sGammaShRa[2]) 
    sigmaSD ~ dgamma(sGammaShRa[1],sGammaShRa[2]) 
    # priori for mu, which consists of a0, a1, a2, a1a2
    a0 ~ dnorm( yMean , 1/(ySD*5)^2 ) 
    #
    for ( j1 in 1:Nx1Lvl ) { a1[j1] ~ dnorm( 0.0 , 1/a1SD^2 ) }
    a1SD ~ dgamma(aGammaShRa[1],aGammaShRa[2]) 
    #
    for ( j2 in 1:Nx2Lvl ) { a2[j2] ~ dnorm( 0.0 , 1/a2SD^2 ) }
    a2SD ~ dgamma(aGammaShRa[1],aGammaShRa[2]) 
    #
    for ( j3 in 1:Nx3Lvl ) { a3[j3] ~ dnorm( 0.0 , 1/a3SD^2 ) }
    a3SD ~ dgamma(aGammaShRa[1],aGammaShRa[2]) 
    #
    for ( j4 in 1:Nx4Lvl ) { a4[j4] ~ dnorm( 0.0 , 1/a4SD^2 ) }
    a4SD ~ dgamma(aGammaShRa[1],aGammaShRa[2]) 
    #
    for ( j1 in 1:Nx1Lvl ) {
            for ( j2 in 1:Nx2Lvl ) { 
                 for ( j3 in 1:Nx3Lvl ) { 
                          for ( j4 in 1:Nx4Lvl ) { 
                                 a1a2a3a4[j1,j2,j3,j4] ~ dnorm( 0.0 , 1/a1a2a3a4SD^2 )
               }
           }
        }
     }
    a1a2a3a4SD ~ dgamma(aGammaShRa[1],aGammaShRa[2]) # or try a folded t (Cauchy)
    # Convert a0,a1[],a2[],a1a2[,] to sum-to-zero b0,b1[],b2[],b1b2[,] :
    for ( j1 in 1:Nx1Lvl ) {
            for ( j2 in 1:Nx2Lvl ) { 
                 for ( j3 in 1:Nx3Lvl ) { 
                          for ( j4 in 1:Nx4Lvl ) { 
                                 m[j1,j2,j3,j4] <- a0 + a1[j1] + a2[j2] + a3[j3] + a4[j4] +a1a2a3a4[j1,j2,j3,j4] # cell means
               }
           }
        }
     }
    b0 <- mean( m[1:Nx1Lvl,1:Nx2Lvl,1:Nx3Lvl,1:Nx4Lvl] )
    for ( j1 in 1:Nx1Lvl ) { b1[j1] <- mean( m[j1,1:Nx2Lvl,1:Nx3Lvl,1:Nx4Lvl] ) - b0 }
    for ( j2 in 1:Nx2Lvl ) { b2[j2] <- mean( m[1:Nx1Lvl,j2,1:Nx3Lvl,1:Nx4Lvl] ) - b0 }
    for ( j3 in 1:Nx3Lvl ) { b3[j3] <- mean( m[1:Nx1Lvl,1:Nx2Lvl, j3,1:Nx4Lvl] ) - b0 }
    for ( j4 in 1:Nx4Lvl ) { b4[j4] <- mean( m[1:Nx1Lvl,1:Nx2Lvl,1:Nx3Lvl,j4] ) - b0 }
    for ( j1 in 1:Nx1Lvl ) {
            for ( j2 in 1:Nx2Lvl ) { 
                 for ( j3 in 1:Nx3Lvl ) { 
                          for ( j4 in 1:Nx4Lvl ) { 
                                 b1b2b3b4[j1,j2,j3,j4] <- m[j1,j2,j3,j4] - ( b0 + b1[j1] + b2[j2] + b3[j3] + b4[j4] )  
               }
           }
        }
     }
  }
  "

# %% [markdown]
# ### 3.2). Function that gets parameters and data for YmetXnom4fac model

# %%
modelParas = function()
    {
    currentdf = df
    # Calculation for external data of this model

      #------------------------------------------------------------------------------
      # THE DATA.
      # Convert data file columns to generic x,y variable names for model:
      # y should be numeric
      y = as.numeric(currentdf[,yName])  
      # x1, x2, x3,x4 should be factor (nominal)
      x1 = as.numeric(as.factor(currentdf[,x1Name]))
      x2 = as.numeric(as.factor(currentdf[,x2Name]))
      x3 = as.numeric(as.factor(currentdf[,x3Name]))
      x4 = as.numeric(as.factor(currentdf[,x4Name]))
      x1levels = levels(as.factor(currentdf[,x1Name]))
      x2levels = levels(as.factor(currentdf[,x2Name]))
      x3levels = levels(as.factor(currentdf[,x3Name]))
      x4levels = levels(as.factor(currentdf[,x4Name]))
      Ntotal = length(y)
      Nx1Lvl = length(unique(x1))
      Nx2Lvl = length(unique(x2))
      Nx3Lvl = length(unique(x3))
      Nx4Lvl = length(unique(x4))
      # Compute scale properties of data, for passing into prior to make the prior
      # vague on the scale of the data. 
      # For prior on baseline, etc.:
      yMean = mean(y)
      ySD = sd(y)
      # For prior on deflections:
      aGammaShRa = unlist( gammaShRaFromModeSD( mode=sd(y)/2 , sd=2*sd(y) ) )
      # For prior on cell SDs:
      cellSDs = aggregate( y , list(x1,x2,x3,x4) , FUN=sd )
      cellSDs = cellSDs[ !is.na(cellSDs$x) ,]
      medianCellSD = median( cellSDs$x , na.rm=TRUE )
      sdCellSD = sd( cellSDs$x , na.rm=TRUE )
    
      sGammaShRa = unlist( gammaShRaFromModeSD( mode=medianCellSD , sd=2*sdCellSD ) )
      # Specify the data in a list for sending to JAGS:
      fourFactsDataList = list(
        y = y ,
        x1 = x1 ,
        x2 = x2 ,
        x3 = x3 ,
        x4 = x4 ,
        Ntotal = Ntotal ,
        Nx1Lvl = Nx1Lvl ,
        Nx2Lvl = Nx2Lvl ,
        Nx3Lvl = Nx3Lvl ,
        Nx4Lvl = Nx4Lvl ,
        # data properties for scaling the prior:
        yMean = yMean ,
        ySD = ySD ,
        medianCellSD = medianCellSD ,
        aGammaShRa = aGammaShRa ,
        sGammaShRa = sGammaShRa
        #a1SD = ySD*5 , #sufficiently large
        #a2SD = ySD*5 #sufficiently large
      )
 
    fourFactsParameters = c( "b0", "b1", "b2", "b3", "b4", "b1b2b3b4", "m"
                                  , "a1SD" , "a2SD" , "a3SD" , "a4SD" , "a1a2a3a4SD" ,"ySigma","sigmaMode" , "sigmaSD" , "nu" 
                                 )
    
    #numSteps = 10000*20*7+2 # num Steps to be updated to achieve ESS of at least 10000.
    numSteps = 10001 #for testing
    testName = paste("AllFactors-",yName,"-","noint",sep="") # location data of the variable y without interactions
    paras <- list(fourFactsDataList = fourFactsDataList, fourFactsParameters = fourFactsParameters, numSteps = numSteps,testName = testName)
    return (paras)
}

# %% [markdown]
# ### 3.3). Function that summarize and plot Bayesian models

# %%
summaryAndPlot = function(paras, mcmcCoda, datFrm)
{
    summaryInfo = smryMCMC(mcmcCoda, datFrm=datFrm, x1Name=x1Name , x2Name=x2Name)
    show(summaryInfo)
    # Save summary Info
    write.table(summaryInfo, file = paste(resultsDir, paras$testName, ".txt"), sep = "\t", quote = FALSE)
    
    parameterNames = varnames(mcmcCoda) 
    show( parameterNames ) # show all parameter names, for reference
    for (i in 1:length(displayParameters)) 
    {
        diagMCMC( codaObject = mcmcCoda , parName = displayParameters[i], parAltName = displayAltParNames[i])
    }
    #figureSaveName = paste(resultsGraphicsDir, currentFeature, "-",x1Name,"-",x2Name)
}

# %% [markdown]
# ## 4). Run YmetXnom4fac model and plot results

# %% [markdown]
# ### 4.1). Run MCMC

# %%
paras_All = modelParas()
mcmcCoda_All = runMCMC(data = paras_All$fourFactsDataList, modelString = fourFactsModel,
                            parameters = paras_All$fourFactsParameters,
                            parNames = NULL, 
                            thinSteps=1,
                            testName = paras_All$testName,
                            mcmcDir=mcmcDir,
                            resultsDir=resultsDir
                            )
# Out:
# [1] "RJO file found and loaded:  calculatedMCMCs/AllFactors-ReactionTimeLog-noint-50000.rjr"
# [1] "Coda file found and loaded:  calculatedMCMCs/AllFactors-ReactionTimeLog-noint-50000.coda"
# [1] "Data file found and loaded:  calculatedMCMCs/AllFactors-ReactionTimeLog-noint-50000.data"

# %% [markdown]
# ### 4.2). Show analysis results in text as well as plot Posteriori distribution

# %% [markdown]
# #### 4.2.1). Parameters summary

# %%
summaryAndPlot(paras_All, mcmcCoda_All, df)
# Out:
#                            Mean       Median         Mode     ESS HDImass
# b0                 3.0082546172  3.008250000  3.007663899 24110.4    0.95
# b1[1] Gridded     -0.0518506115 -0.051863700 -0.051557305 12419.9    0.95
# b1[2] Random       0.0518506115  0.051863700  0.051557305 12419.9    0.95
# b2[1] Center      -0.0840089300 -0.084015550 -0.083744625 11195.7    0.95
# b2[2] Periphery    0.0840089300  0.084015550  0.083744625 11195.7    0.95
# b3[1]             -0.3441846980 -0.344153000 -0.344294110 17110.2    0.95
# b3[2]              0.0713355042  0.071316900  0.070551637 14359.1    0.95
# b3[3]              0.2728491956  0.272826000  0.273116951 17365.2    0.95
# b4[1]             -0.1950698096 -0.195060500 -0.193914289 19432.0    0.95
# b4[2]             -0.0848109205 -0.084773850 -0.084014129 23581.8    0.95
# b4[3]              0.0594779778  0.059471700  0.059456786 16800.7    0.95
# b4[4]              0.2204027505  0.220301500  0.219574594 21225.8    0.95
# b1b2b3b4[1,1,1,1]  0.2195781161  0.219522000  0.220226437 21293.0    0.95
# b1b2b3b4[2,1,1,1]  0.2207869783  0.220792000  0.219315880 27037.5    0.95
# b1b2b3b4[1,2,1,1]  0.0880534800  0.088051400  0.087627154 26947.7    0.95
# b1b2b3b4[2,2,1,1]  0.0615775244  0.061472900  0.062576462 26382.0    0.95
# b1b2b3b4[1,1,2,1]  0.0135007442  0.013356850  0.013917471 30132.2    0.95
# b1b2b3b4[2,1,2,1] -0.0935491293 -0.093497250 -0.091338971 11795.3    0.95
# b1b2b3b4[1,2,2,1] -0.1245299078 -0.124832000 -0.123046571 24688.6    0.95
# b1b2b3b4[2,2,2,1] -0.1682169282 -0.168206500 -0.167748331 15529.5    0.95
# b1b2b3b4[1,1,3,1]  0.0661084909  0.066103650  0.069173685 30528.6    0.95
# b1b2b3b4[2,1,3,1] -0.1171668149 -0.117184500 -0.113248046 27051.9    0.95
# b1b2b3b4[1,2,3,1] -0.1097273027 -0.110160000 -0.111242049 28224.4    0.95
# b1b2b3b4[2,2,3,1] -0.0564152524 -0.056437200 -0.054708623 28527.1    0.95
# b1b2b3b4[1,1,1,2]  0.1880683745  0.188278000  0.190941834 22833.3    0.95
# b1b2b3b4[2,1,1,2]  0.1157587782  0.115832500  0.116936985 29011.8    0.95
# b1b2b3b4[1,2,1,2]  0.0347423691  0.034466350  0.031302747 30227.9    0.95
# b1b2b3b4[2,2,1,2]  0.0190848928  0.019112400  0.017834568 30270.6    0.95
# b1b2b3b4[1,1,2,2] -0.0817109478 -0.081979800 -0.084564446 24172.1    0.95
# b1b2b3b4[2,1,2,2] -0.0913637141 -0.091646300 -0.091852894 24956.4    0.95
# b1b2b3b4[1,2,2,2] -0.0703236178 -0.070344800 -0.071196035 28214.9    0.95
# b1b2b3b4[2,2,2,2]  0.0006206752  0.000347032 -0.003036590 30018.3    0.95
# b1b2b3b4[1,1,3,2] -0.0812524642 -0.082198450 -0.085710569 28480.9    0.95
# b1b2b3b4[2,1,3,2] -0.0946842574 -0.095509050 -0.096794761 26322.9    0.95
# b1b2b3b4[1,2,3,2]  0.1276531023  0.127973500  0.132828436 26475.1    0.95
# b1b2b3b4[2,2,3,2] -0.0665931898 -0.067182500 -0.070765225 29568.7    0.95
# b1b2b3b4[1,1,1,3]  0.0386530026  0.038483050  0.036460770 27377.3    0.95
# b1b2b3b4[2,1,1,3] -0.0667367196 -0.066598700 -0.068276617 22629.8    0.95
# b1b2b3b4[1,2,1,3] -0.0664812006 -0.066591050 -0.066459631 27534.5    0.95
# b1b2b3b4[2,2,1,3] -0.2365179959 -0.236867500 -0.233347136 26803.7    0.95
# b1b2b3b4[1,1,2,3] -0.0881301622 -0.088358050 -0.091193016 29852.5    0.95
# b1b2b3b4[2,1,2,3]  0.0185859369  0.018393850  0.018156856 29408.6    0.95
# b1b2b3b4[1,2,2,3]  0.0322729235  0.032465300  0.029333390 29559.8    0.95
# b1b2b3b4[2,2,2,3]  0.1267514484  0.126567000  0.124525760 30331.0    0.95
# b1b2b3b4[1,1,3,3] -0.0338834426 -0.034761600 -0.037092832 25331.7    0.95
# b1b2b3b4[2,1,3,3]  0.0580231587  0.057677000  0.061549810 27600.7    0.95
# b1b2b3b4[1,2,3,3]  0.1269342914  0.126804500  0.130032314 29441.6    0.95
# b1b2b3b4[2,2,3,3]  0.0905287601  0.090551600  0.091916446 29419.9    0.95
# b1b2b3b4[1,1,1,4] -0.0012044108 -0.001325670 -0.003720312 28380.7    0.95
# b1b2b3b4[2,1,1,4] -0.1483622573 -0.148557000 -0.154031793 28070.7    0.95
# b1b2b3b4[1,2,1,4] -0.1800014408 -0.179812000 -0.182797530 25292.7    0.95
# b1b2b3b4[2,2,1,4] -0.2869994974 -0.287244500 -0.290370232 26345.4    0.95
# b1b2b3b4[1,1,2,4] -0.0434234507 -0.043820450 -0.042876817 29254.9    0.95
# b1b2b3b4[2,1,2,4]  0.1764950609  0.176376500  0.173661007 21943.3    0.95
# b1b2b3b4[1,2,2,4] -0.0673746412 -0.067257950 -0.061911865 29625.3    0.95
# b1b2b3b4[2,2,2,4]  0.4603957138  0.461334000  0.460773437 21028.9    0.95
# b1b2b3b4[1,1,3,4] -0.1274362034 -0.127659500 -0.122977094 26108.2    0.95
# b1b2b3b4[2,1,3,4] -0.0466546653 -0.046825950 -0.045018731 26703.1    0.95
# b1b2b3b4[1,2,3,4]  0.1399142988  0.140091500  0.139259177 28891.3    0.95
# b1b2b3b4[2,2,3,4]  0.1246514980  0.124967500  0.124792851 30474.4    0.95
# m[1,1,1,1]         2.5527187002  2.552660000  2.552997954 32390.9    0.95
# m[2,1,1,1]         2.6576287950  2.657690000  2.655815033 32003.5    0.95
# m[1,2,1,1]         2.5892119352  2.588940000  2.586677582 33339.8    0.95
# m[2,2,1,1]         2.6664371934  2.666390000  2.666939599 31180.7    0.95
# m[1,1,2,1]         2.7621615174  2.761980000  2.758906830 34862.2    0.95
# m[2,1,2,1]         2.7588128690  2.758690000  2.759965127 34699.5    0.95
# m[1,2,2,1]         2.7921487350  2.791600000  2.785588707 29242.1    0.95
# m[2,2,2,1]         2.8521629588  2.851845000  2.849751621 34502.9    0.95
# m[1,1,3,1]         3.0162829544  3.015985000  3.015286197 29438.8    0.95
# m[2,1,3,1]         2.9367088612  2.936550000  2.939589441 32002.2    0.95
# m[1,2,3,1]         3.0084650488  3.007790000  3.007229071 29261.0    0.95
# m[2,2,3,1]         3.1654783286  3.165730000  3.170092457 31960.8    0.95
# m[1,1,1,2]         2.6314678574  2.631870000  2.632069837 28845.5    0.95
# m[2,1,1,2]         2.6628594580  2.663060000  2.667128483 32055.5    0.95
# m[1,2,1,2]         2.6461597040  2.645895000  2.645519095 31072.9    0.95
# m[2,2,1,2]         2.7342034254  2.734440000  2.739124452 29689.0    0.95
# m[1,1,2,2]         2.7772087268  2.776745000  2.779442917 29800.7    0.95
# m[2,1,2,2]         2.8712571788  2.870670000  2.868669503 31221.7    0.95
# m[1,2,2,2]         2.9566139216  2.956570000  2.955527880 33262.9    0.95
# m[2,2,2,2]         3.1312594368  3.130940000  3.132511895 30867.0    0.95
# m[1,1,3,2]         2.9791809008  2.978115000  2.982305410 27169.0    0.95
# m[2,1,3,2]         3.0694503158  3.068290000  3.071633981 22573.4    0.95
# m[1,2,3,2]         3.3561043202  3.356510000  3.354990830 30500.9    0.95
# m[2,2,3,2]         3.2655592612  3.264950000  3.265214083 30429.0    0.95
# m[1,1,1,3]         2.6263414066  2.625995000  2.627700190 28790.0    0.95
# m[2,1,1,3]         2.6246528790  2.624840000  2.624938876 33935.7    0.95
# m[1,2,1,3]         2.6892250224  2.689070000  2.687917638 32810.9    0.95
# m[2,2,1,3]         2.6228894426  2.622405000  2.623082884 28494.4    0.95
# m[1,1,2,3]         2.9150783994  2.914940000  2.916265386 33360.9    0.95
# m[2,1,2,3]         3.1254957602  3.124930000  3.121808113 20286.9    0.95
# m[1,2,2,3]         3.2034993512  3.203700000  3.204562770 29365.8    0.95
# m[2,2,2,3]         3.4016790986  3.401590000  3.403203822 30176.0    0.95
# m[1,1,3,3]         3.1708388202  3.169900000  3.174552529 19770.7    0.95
# m[2,1,3,3]         3.3664466576  3.366110000  3.359926649 20556.5    0.95
# m[1,2,3,3]         3.4996744150  3.499445000  3.498858917 27002.6    0.95
# m[2,2,3,3]         3.5669700706  3.567080000  3.570833350 30215.4    0.95
# m[1,1,1,4]         2.7474087144  2.747035000  2.743955796 30626.0    0.95
# m[2,1,1,4]         2.7039520954  2.703595000  2.698434306 30706.4    0.95
# m[1,2,1,4]         2.7366295746  2.736580000  2.736817002 23638.5    0.95
# m[2,2,1,4]         2.7333327500  2.732760000  2.730094724 29785.8    0.95
# m[1,1,2,4]         3.1207099110  3.120030000  3.118323108 30337.4    0.95
# m[2,1,2,4]         3.4443296512  3.444250000  3.438595892 18035.1    0.95
# m[1,2,2,4]         3.2647765608  3.264820000  3.264575375 31554.3    0.95
# m[2,2,2,4]         3.8962481398  3.897870000  3.898152749 17832.8    0.95
# m[1,1,3,4]         3.2382108086  3.237765000  3.239975406 22151.7    0.95
# m[2,1,3,4]         3.4226935998  3.422510000  3.423847271 20733.2    0.95
# m[1,2,3,4]         3.6735792120  3.673570000  3.668056008 23758.4    0.95
# m[2,2,3,4]         3.7620176178  3.762080000  3.756838790 27549.4    0.95
# a1SD               0.3621422726  0.240558000  0.088762498   673.6    0.95
# a2SD               0.4593350151  0.324201000  0.142541474   745.8    0.95
# a3SD               0.5392702885  0.445618000  0.289217135  1187.8    0.95
# a4SD               0.2720541415  0.225075000  0.173005105  1154.6    0.95
# a1a2a3a4SD         0.1585788593  0.156864000  0.155423553  5254.4    0.95
# ySigma[1,1,1,1]    0.1186987452  0.116905000  0.114322125 23389.8    0.95
# ySigma[2,1,1,1]    0.1359991846  0.133953500  0.130953400 24309.2    0.95
# ySigma[1,2,1,1]    0.1394053768  0.137456000  0.133626152 25365.9    0.95
# ySigma[2,2,1,1]    0.1436954762  0.141309500  0.136264883 21526.7    0.95
# ySigma[1,1,2,1]    0.1142862501  0.112447000  0.107855181 23804.7    0.95
# ySigma[2,1,2,1]    0.0820376768  0.080686950  0.077529480 23284.5    0.95
# ySigma[1,2,2,1]    0.1434079834  0.141240500  0.137429765 22036.5    0.95
# ySigma[2,2,2,1]    0.0929706849  0.091264450  0.088885013 21992.7    0.95
# ySigma[1,1,3,1]    0.2159399858  0.213146000  0.206301830 26143.4    0.95
# ySigma[2,1,3,1]    0.1496861854  0.147595500  0.144121985 25384.3    0.95
# ySigma[1,2,3,1]    0.1909475601  0.188421000  0.182995384 22947.9    0.95
# ySigma[2,2,3,1]    0.1767205313  0.174200500  0.169351813 23798.5    0.95
# ySigma[1,1,1,2]    0.1443275287  0.142163000  0.140740405 23788.1    0.95
# ySigma[2,1,1,2]    0.1456599686  0.143579500  0.139839471 24972.2    0.95
# ySigma[1,2,1,2]    0.1781174294  0.174969500  0.167693377 21691.1    0.95
# ySigma[2,2,1,2]    0.1927694987  0.190147500  0.188464885 25014.9    0.95
# ySigma[1,1,2,2]    0.1175609800  0.115612000  0.111635322 20480.1    0.95
# ySigma[2,1,2,2]    0.1529723073  0.150415000  0.146766518 21690.2    0.95
# ySigma[1,2,2,2]    0.1365237065  0.134441000  0.130505998 24772.4    0.95
# ySigma[2,2,2,2]    0.2007416191  0.198124500  0.190817759 25357.6    0.95
# ySigma[1,1,3,2]    0.2630769290  0.259380000  0.252959622 22836.9    0.95
# ySigma[2,1,3,2]    0.2621371574  0.258997500  0.254514862 23846.3    0.95
# ySigma[1,2,3,2]    0.2219212702  0.218885500  0.210041235 23922.9    0.95
# ySigma[2,2,3,2]    0.2199293887  0.216813500  0.209277439 24379.5    0.95
# ySigma[1,1,1,3]    0.1673657410  0.164130000  0.160954465 18543.2    0.95
# ySigma[2,1,1,3]    0.1153433762  0.113577000  0.110689083 24813.8    0.95
# ySigma[1,2,1,3]    0.1421906808  0.139780000  0.133254936 21805.1    0.95
# ySigma[2,2,1,3]    0.1841285605  0.181024000  0.176554663 20945.5    0.95
# ySigma[1,1,2,3]    0.1597307401  0.157673000  0.153340655 24900.3    0.95
# ySigma[2,1,2,3]    0.2986613343  0.295352000  0.294529909 24704.3    0.95
# ySigma[1,2,2,3]    0.2322485120  0.229614000  0.222493466 25360.2    0.95
# ySigma[2,2,2,3]    0.2298895427  0.226862000  0.224559000 23502.1    0.95
# ySigma[1,1,3,3]    0.3865007894  0.382383500  0.373556657 23051.2    0.95
# ySigma[2,1,3,3]    0.3480411818  0.343333000  0.335921742 24786.2    0.95
# ySigma[1,2,3,3]    0.2761717206  0.272529500  0.266428491 24323.7    0.95
# ySigma[2,2,3,3]    0.2488211268  0.245516000  0.241014518 23128.1    0.95
# ySigma[1,1,1,4]    0.2256141214  0.222610000  0.219208939 23791.7    0.95
# ySigma[2,1,1,4]    0.2151337299  0.212320000  0.208090482 25149.6    0.95
# ySigma[1,2,1,4]    0.2737008021  0.269780000  0.260897702 22138.0    0.95
# ySigma[2,2,1,4]    0.2274270550  0.224788500  0.215369296 23774.8    0.95
# ySigma[1,1,2,4]    0.2326078849  0.229619500  0.221587063 24763.7    0.95
# ySigma[2,1,2,4]    0.4199391273  0.415494500  0.410276073 23900.8    0.95
# ySigma[1,2,2,4]    0.2435568433  0.240586500  0.234394682 25742.1    0.95
# ySigma[2,2,2,4]    0.2832341067  0.279307500  0.275982912 21393.9    0.95
# ySigma[1,1,3,4]    0.3950707270  0.390737500  0.381086414 23820.6    0.95
# ySigma[2,1,3,4]    0.4059688585  0.401578500  0.394496939 23994.7    0.95
# ySigma[1,2,3,4]    0.3450877605  0.340993000  0.335612408 22602.2    0.95
# ySigma[2,2,3,4]    0.2911339702  0.287579500  0.282841569 25964.0    0.95
# sigmaMode          0.1771143660  0.177367500  0.177854665 17847.0    0.95
# sigmaSD            0.0942367310  0.092899950  0.088605308 15678.6    0.95
# nu                 5.5441382272  5.450855000  5.275277646  8761.5    0.95
#                        HDIlow     HDIhigh CompVal PcntGtCompVal ROPElow
# b0                 2.99409000  3.02190000      NA            NA      NA
# b1[1] Gridded     -0.06542460 -0.03847790      NA            NA      NA
# b1[2] Random       0.03847790  0.06542460      NA            NA      NA
# b2[1] Center      -0.09753990 -0.07082320      NA            NA      NA
# b2[2] Periphery    0.07082320  0.09753990      NA            NA      NA
# b3[1]             -0.36141700 -0.32702600      NA            NA      NA
# b3[2]              0.05307350  0.08988440      NA            NA      NA
# b3[3]              0.25127100  0.29494000      NA            NA      NA
# b4[1]             -0.21346600 -0.17726800      NA            NA      NA
# b4[2]             -0.10536900 -0.06381250      NA            NA      NA
# b4[3]              0.03541630  0.08382780      NA            NA      NA
# b4[4]              0.19176300  0.24930200      NA            NA      NA
# b1b2b3b4[1,1,1,1]  0.17218700  0.26777500      NA            NA      NA
# b1b2b3b4[2,1,1,1]  0.16706200  0.27199400      NA            NA      NA
# b1b2b3b4[1,2,1,1]  0.03241120  0.14244100      NA            NA      NA
# b1b2b3b4[2,2,1,1]  0.00865028  0.11649000      NA            NA      NA
# b1b2b3b4[1,1,2,1] -0.03243110  0.05908530      NA            NA      NA
# b1b2b3b4[2,1,2,1] -0.13423000 -0.05319630      NA            NA      NA
# b1b2b3b4[1,2,2,1] -0.17805000 -0.07011710      NA            NA      NA
# b1b2b3b4[2,2,2,1] -0.21135600 -0.12506500      NA            NA      NA
# b1b2b3b4[1,1,3,1] -0.01206200  0.14719800      NA            NA      NA
# b1b2b3b4[2,1,3,1] -0.17727300 -0.05974030      NA            NA      NA
# b1b2b3b4[1,2,3,1] -0.17815800 -0.03961800      NA            NA      NA
# b1b2b3b4[2,2,3,1] -0.12047900  0.01018980      NA            NA      NA
# b1b2b3b4[1,1,1,2]  0.13116300  0.24150700      NA            NA      NA
# b1b2b3b4[2,1,1,2]  0.06127800  0.17370600      NA            NA      NA
# b1b2b3b4[1,2,1,2] -0.02967640  0.09998780      NA            NA      NA
# b1b2b3b4[2,2,1,2] -0.04831100  0.08968210      NA            NA      NA
# b1b2b3b4[1,1,2,2] -0.13054000 -0.03438130      NA            NA      NA
# b1b2b3b4[2,1,2,2] -0.15113000 -0.03234840      NA            NA      NA
# b1b2b3b4[1,2,2,2] -0.12389200 -0.01480940      NA            NA      NA
# b1b2b3b4[2,2,2,2] -0.07048180  0.07529030      NA            NA      NA
# b1b2b3b4[1,1,3,2] -0.17118500  0.01036670      NA            NA      NA
# b1b2b3b4[2,1,3,2] -0.18754400 -0.00174903      NA            NA      NA
# b1b2b3b4[1,2,3,2]  0.04691620  0.21191700      NA            NA      NA
# b1b2b3b4[2,2,3,2] -0.14381600  0.01338720      NA            NA      NA
# b1b2b3b4[1,1,1,3] -0.02142670  0.10149500      NA            NA      NA
# b1b2b3b4[2,1,1,3] -0.11703200 -0.01661340      NA            NA      NA
# b1b2b3b4[1,2,1,3] -0.12532100 -0.01159930      NA            NA      NA
# b1b2b3b4[2,2,1,3] -0.30290900 -0.16925700      NA            NA      NA
# b1b2b3b4[1,1,2,3] -0.15001700 -0.02366500      NA            NA      NA
# b1b2b3b4[2,1,2,3] -0.08178100  0.11906900      NA            NA      NA
# b1b2b3b4[1,2,2,3] -0.04863770  0.11340000      NA            NA      NA
# b1b2b3b4[2,2,2,3]  0.04818680  0.20957100      NA            NA      NA
# b1b2b3b4[1,1,3,3] -0.16194000  0.09719090      NA            NA      NA
# b1b2b3b4[2,1,3,3] -0.06206080  0.18016300      NA            NA      NA
# b1b2b3b4[1,2,3,3]  0.02607810  0.22570200      NA            NA      NA
# b1b2b3b4[2,2,3,3]  0.00222864  0.17788100      NA            NA      NA
# b1b2b3b4[1,1,1,4] -0.08081940  0.07887720      NA            NA      NA
# b1b2b3b4[2,1,1,4] -0.22695700 -0.06831440      NA            NA      NA
# b1b2b3b4[1,2,1,4] -0.27343800 -0.08302340      NA            NA      NA
# b1b2b3b4[2,2,1,4] -0.36891900 -0.20369400      NA            NA      NA
# b1b2b3b4[1,1,2,4] -0.12724300  0.04023170      NA            NA      NA
# b1b2b3b4[2,1,2,4]  0.04093910  0.31426500      NA            NA      NA
# b1b2b3b4[1,2,2,4] -0.15446100  0.01778830      NA            NA      NA
# b1b2b3b4[2,2,2,4]  0.35287100  0.56585600      NA            NA      NA
# b1b2b3b4[1,1,3,4] -0.25987200  0.00115015      NA            NA      NA
# b1b2b3b4[2,1,3,4] -0.17521700  0.08249220      NA            NA      NA
# b1b2b3b4[1,2,3,4]  0.02336040  0.25576700      NA            NA      NA
# b1b2b3b4[2,2,3,4]  0.02005790  0.22556500      NA            NA      NA
# m[1,1,1,1]         2.50533000  2.59828000      NA            NA      NA
# m[2,1,1,1]         2.60234000  2.71178000      NA            NA      NA
# m[1,2,1,1]         2.53493000  2.64482000      NA            NA      NA
# m[2,2,1,1]         2.61156000  2.72093000      NA            NA      NA
# m[1,1,2,1]         2.71784000  2.80654000      NA            NA      NA
# m[2,1,2,1]         2.72611000  2.78994000      NA            NA      NA
# m[1,2,2,1]         2.73725000  2.84856000      NA            NA      NA
# m[2,2,2,1]         2.81562000  2.89032000      NA            NA      NA
# m[1,1,3,1]         2.92854000  3.10398000      NA            NA      NA
# m[2,1,3,1]         2.87739000  2.99553000      NA            NA      NA
# m[1,2,3,1]         2.93217000  3.08244000      NA            NA      NA
# m[2,2,3,1]         3.09378000  3.23514000      NA            NA      NA
# m[1,1,1,2]         2.57422000  2.68618000      NA            NA      NA
# m[2,1,1,2]         2.60361000  2.71763000      NA            NA      NA
# m[1,2,1,2]         2.57722000  2.71475000      NA            NA      NA
# m[2,2,1,2]         2.65968000  2.80980000      NA            NA      NA
# m[1,1,2,2]         2.73178000  2.82456000      NA            NA      NA
# m[2,1,2,2]         2.81237000  2.93165000      NA            NA      NA
# m[1,2,2,2]         2.90139000  3.01104000      NA            NA      NA
# m[2,2,2,2]         3.05210000  3.20990000      NA            NA      NA
# m[1,1,3,2]         2.88076000  3.08520000      NA            NA      NA
# m[2,1,3,2]         2.96710000  3.17795000      NA            NA      NA
# m[1,2,3,2]         3.26351000  3.44383000      NA            NA      NA
# m[2,2,3,2]         3.17928000  3.35243000      NA            NA      NA
# m[1,1,1,3]         2.56296000  2.69033000      NA            NA      NA
# m[2,1,1,3]         2.57892000  2.67014000      NA            NA      NA
# m[1,2,1,3]         2.63357000  2.74467000      NA            NA      NA
# m[2,2,1,3]         2.55346000  2.69555000      NA            NA      NA
# m[1,1,2,3]         2.85387000  2.98018000      NA            NA      NA
# m[2,1,2,3]         3.00979000  3.23994000      NA            NA      NA
# m[1,2,2,3]         3.11045000  3.29164000      NA            NA      NA
# m[2,2,2,3]         3.31441000  3.49229000      NA            NA      NA
# m[1,1,3,3]         3.02345000  3.32688000      NA            NA      NA
# m[2,1,3,3]         3.22671000  3.50801000      NA            NA      NA
# m[1,2,3,3]         3.38695000  3.61370000      NA            NA      NA
# m[2,2,3,3]         3.47115000  3.66512000      NA            NA      NA
# m[1,1,1,4]         2.65964000  2.83342000      NA            NA      NA
# m[2,1,1,4]         2.61962000  2.78974000      NA            NA      NA
# m[1,2,1,4]         2.62753000  2.84185000      NA            NA      NA
# m[2,2,1,4]         2.64374000  2.82253000      NA            NA      NA
# m[1,1,2,4]         3.03116000  3.21154000      NA            NA      NA
# m[2,1,2,4]         3.28467000  3.60669000      NA            NA      NA
# m[1,2,2,4]         3.17444000  3.36128000      NA            NA      NA
# m[2,2,2,4]         3.77408000  4.01566000      NA            NA      NA
# m[1,1,3,4]         3.08169000  3.38520000      NA            NA      NA
# m[2,1,3,4]         3.27107000  3.57051000      NA            NA      NA
# m[1,2,3,4]         3.53833000  3.80689000      NA            NA      NA
# m[2,2,3,4]         3.64703000  3.88001000      NA            NA      NA
# a1SD               0.00101596  1.09763000      NA            NA      NA
# a2SD               0.02856020  1.29501000      NA            NA      NA
# a3SD               0.12768700  1.20120000      NA            NA      NA
# a4SD               0.06792930  0.58074500      NA            NA      NA
# a1a2a3a4SD         0.12067000  0.19818000      NA            NA      NA
# ySigma[1,1,1,1]    0.08570350  0.15584500      NA            NA      NA
# ySigma[2,1,1,1]    0.09658160  0.17783800      NA            NA      NA
# ySigma[1,2,1,1]    0.10130100  0.18229700      NA            NA      NA
# ySigma[2,2,1,1]    0.09746420  0.19304400      NA            NA      NA
# ySigma[1,1,2,1]    0.08008630  0.15046900      NA            NA      NA
# ySigma[2,1,2,1]    0.05731290  0.10907300      NA            NA      NA
# ySigma[1,2,2,1]    0.10054900  0.19105800      NA            NA      NA
# ySigma[2,2,2,1]    0.06525620  0.12494900      NA            NA      NA
# ySigma[1,1,3,1]    0.15920300  0.28028800      NA            NA      NA
# ySigma[2,1,3,1]    0.10743400  0.19379400      NA            NA      NA
# ySigma[1,2,3,1]    0.13549400  0.25002400      NA            NA      NA
# ySigma[2,2,3,1]    0.12688700  0.23049600      NA            NA      NA
# ySigma[1,1,1,2]    0.10084300  0.19313500      NA            NA      NA
# ySigma[2,1,1,2]    0.10336800  0.19183500      NA            NA      NA
# ySigma[1,2,1,2]    0.12135300  0.23939100      NA            NA      NA
# ySigma[2,2,1,2]    0.13788600  0.25152800      NA            NA      NA
# ySigma[1,1,2,2]    0.07979950  0.15881600      NA            NA      NA
# ySigma[2,1,2,2]    0.10551000  0.20469000      NA            NA      NA
# ySigma[1,2,2,2]    0.09651100  0.18122600      NA            NA      NA
# ySigma[2,2,2,2]    0.14658600  0.26026900      NA            NA      NA
# ySigma[1,1,3,2]    0.18876800  0.34486700      NA            NA      NA
# ySigma[2,1,3,2]    0.18899100  0.33846700      NA            NA      NA
# ySigma[1,2,3,2]    0.15949400  0.29196100      NA            NA      NA
# ySigma[2,2,3,2]    0.15563300  0.28761400      NA            NA      NA
# ySigma[1,1,1,3]    0.10961600  0.23125900      NA            NA      NA
# ySigma[2,1,1,3]    0.08268230  0.15248900      NA            NA      NA
# ySigma[1,2,1,3]    0.09733100  0.19028000      NA            NA      NA
# ySigma[2,2,1,3]    0.12569600  0.24516800      NA            NA      NA
# ySigma[1,1,2,3]    0.11645100  0.20788000      NA            NA      NA
# ySigma[2,1,2,3]    0.21834900  0.38120600      NA            NA      NA
# ySigma[1,2,2,3]    0.17026400  0.29970600      NA            NA      NA
# ySigma[2,2,2,3]    0.16362800  0.30141700      NA            NA      NA
# ySigma[1,1,3,3]    0.28796500  0.49756200      NA            NA      NA
# ySigma[2,1,3,3]    0.25521500  0.45044300      NA            NA      NA
# ySigma[1,2,3,3]    0.19766600  0.36430700      NA            NA      NA
# ySigma[2,2,3,3]    0.17657700  0.32656000      NA            NA      NA
# ySigma[1,1,1,4]    0.16099600  0.29548700      NA            NA      NA
# ySigma[2,1,1,4]    0.15904900  0.27876800      NA            NA      NA
# ySigma[1,2,1,4]    0.19419300  0.36062500      NA            NA      NA
# ySigma[2,2,1,4]    0.16324100  0.29373500      NA            NA      NA
# ySigma[1,1,2,4]    0.17006000  0.30167200      NA            NA      NA
# ySigma[2,1,2,4]    0.31584300  0.53684000      NA            NA      NA
# ySigma[1,2,2,4]    0.17796800  0.31544700      NA            NA      NA
# ySigma[2,2,2,4]    0.20208400  0.37059100      NA            NA      NA
# ySigma[1,1,3,4]    0.29365800  0.49993000      NA            NA      NA
# ySigma[2,1,3,4]    0.30241900  0.51853900      NA            NA      NA
# ySigma[1,2,3,4]    0.24867100  0.45313500      NA            NA      NA
# ySigma[2,2,3,4]    0.21417500  0.37660900      NA            NA      NA
# sigmaMode          0.14702800  0.20653800      NA            NA      NA
# sigmaSD            0.06939030  0.12121300      NA            NA      NA
# nu                 4.08674000  7.15767000      NA            NA      NA
#                   ROPEhigh PcntLtROPE PcntInROPE PcntGtROPE
# b0                      NA         NA         NA         NA
# b1[1] Gridded           NA         NA         NA         NA
# b1[2] Random            NA         NA         NA         NA
# b2[1] Center            NA         NA         NA         NA
# b2[2] Periphery         NA         NA         NA         NA
# b3[1]                   NA         NA         NA         NA
# b3[2]                   NA         NA         NA         NA
# b3[3]                   NA         NA         NA         NA
# b4[1]                   NA         NA         NA         NA
# b4[2]                   NA         NA         NA         NA
# b4[3]                   NA         NA         NA         NA
# b4[4]                   NA         NA         NA         NA
# b1b2b3b4[1,1,1,1]       NA         NA         NA         NA
# b1b2b3b4[2,1,1,1]       NA         NA         NA         NA
# b1b2b3b4[1,2,1,1]       NA         NA         NA         NA
# b1b2b3b4[2,2,1,1]       NA         NA         NA         NA
# b1b2b3b4[1,1,2,1]       NA         NA         NA         NA
# b1b2b3b4[2,1,2,1]       NA         NA         NA         NA
# b1b2b3b4[1,2,2,1]       NA         NA         NA         NA
# b1b2b3b4[2,2,2,1]       NA         NA         NA         NA
# b1b2b3b4[1,1,3,1]       NA         NA         NA         NA
# b1b2b3b4[2,1,3,1]       NA         NA         NA         NA
# b1b2b3b4[1,2,3,1]       NA         NA         NA         NA
# b1b2b3b4[2,2,3,1]       NA         NA         NA         NA
# b1b2b3b4[1,1,1,2]       NA         NA         NA         NA
# b1b2b3b4[2,1,1,2]       NA         NA         NA         NA
# b1b2b3b4[1,2,1,2]       NA         NA         NA         NA
# b1b2b3b4[2,2,1,2]       NA         NA         NA         NA
# b1b2b3b4[1,1,2,2]       NA         NA         NA         NA
# b1b2b3b4[2,1,2,2]       NA         NA         NA         NA
# b1b2b3b4[1,2,2,2]       NA         NA         NA         NA
# b1b2b3b4[2,2,2,2]       NA         NA         NA         NA
# b1b2b3b4[1,1,3,2]       NA         NA         NA         NA
# b1b2b3b4[2,1,3,2]       NA         NA         NA         NA
# b1b2b3b4[1,2,3,2]       NA         NA         NA         NA
# b1b2b3b4[2,2,3,2]       NA         NA         NA         NA
# b1b2b3b4[1,1,1,3]       NA         NA         NA         NA
# b1b2b3b4[2,1,1,3]       NA         NA         NA         NA
# b1b2b3b4[1,2,1,3]       NA         NA         NA         NA
# b1b2b3b4[2,2,1,3]       NA         NA         NA         NA
# b1b2b3b4[1,1,2,3]       NA         NA         NA         NA
# b1b2b3b4[2,1,2,3]       NA         NA         NA         NA
# b1b2b3b4[1,2,2,3]       NA         NA         NA         NA
# b1b2b3b4[2,2,2,3]       NA         NA         NA         NA
# b1b2b3b4[1,1,3,3]       NA         NA         NA         NA
# b1b2b3b4[2,1,3,3]       NA         NA         NA         NA
# b1b2b3b4[1,2,3,3]       NA         NA         NA         NA
# b1b2b3b4[2,2,3,3]       NA         NA         NA         NA
# b1b2b3b4[1,1,1,4]       NA         NA         NA         NA
# b1b2b3b4[2,1,1,4]       NA         NA         NA         NA
# b1b2b3b4[1,2,1,4]       NA         NA         NA         NA
# b1b2b3b4[2,2,1,4]       NA         NA         NA         NA
# b1b2b3b4[1,1,2,4]       NA         NA         NA         NA
# b1b2b3b4[2,1,2,4]       NA         NA         NA         NA
# b1b2b3b4[1,2,2,4]       NA         NA         NA         NA
# b1b2b3b4[2,2,2,4]       NA         NA         NA         NA
# b1b2b3b4[1,1,3,4]       NA         NA         NA         NA
# b1b2b3b4[2,1,3,4]       NA         NA         NA         NA
# b1b2b3b4[1,2,3,4]       NA         NA         NA         NA
# b1b2b3b4[2,2,3,4]       NA         NA         NA         NA
# m[1,1,1,1]              NA         NA         NA         NA
# m[2,1,1,1]              NA         NA         NA         NA
# m[1,2,1,1]              NA         NA         NA         NA
# m[2,2,1,1]              NA         NA         NA         NA
# m[1,1,2,1]              NA         NA         NA         NA
# m[2,1,2,1]              NA         NA         NA         NA
# m[1,2,2,1]              NA         NA         NA         NA
# m[2,2,2,1]              NA         NA         NA         NA
# m[1,1,3,1]              NA         NA         NA         NA
# m[2,1,3,1]              NA         NA         NA         NA
# m[1,2,3,1]              NA         NA         NA         NA
# m[2,2,3,1]              NA         NA         NA         NA
# m[1,1,1,2]              NA         NA         NA         NA
# m[2,1,1,2]              NA         NA         NA         NA
# m[1,2,1,2]              NA         NA         NA         NA
# m[2,2,1,2]              NA         NA         NA         NA
# m[1,1,2,2]              NA         NA         NA         NA
# m[2,1,2,2]              NA         NA         NA         NA
# m[1,2,2,2]              NA         NA         NA         NA
# m[2,2,2,2]              NA         NA         NA         NA
# m[1,1,3,2]              NA         NA         NA         NA
# m[2,1,3,2]              NA         NA         NA         NA
# m[1,2,3,2]              NA         NA         NA         NA
# m[2,2,3,2]              NA         NA         NA         NA
# m[1,1,1,3]              NA         NA         NA         NA
# m[2,1,1,3]              NA         NA         NA         NA
# m[1,2,1,3]              NA         NA         NA         NA
# m[2,2,1,3]              NA         NA         NA         NA
# m[1,1,2,3]              NA         NA         NA         NA
# m[2,1,2,3]              NA         NA         NA         NA
# m[1,2,2,3]              NA         NA         NA         NA
# m[2,2,2,3]              NA         NA         NA         NA
# m[1,1,3,3]              NA         NA         NA         NA
# m[2,1,3,3]              NA         NA         NA         NA
# m[1,2,3,3]              NA         NA         NA         NA
# m[2,2,3,3]              NA         NA         NA         NA
# m[1,1,1,4]              NA         NA         NA         NA
# m[2,1,1,4]              NA         NA         NA         NA
# m[1,2,1,4]              NA         NA         NA         NA
# m[2,2,1,4]              NA         NA         NA         NA
# m[1,1,2,4]              NA         NA         NA         NA
# m[2,1,2,4]              NA         NA         NA         NA
# m[1,2,2,4]              NA         NA         NA         NA
# m[2,2,2,4]              NA         NA         NA         NA
# m[1,1,3,4]              NA         NA         NA         NA
# m[2,1,3,4]              NA         NA         NA         NA
# m[1,2,3,4]              NA         NA         NA         NA
# m[2,2,3,4]              NA         NA         NA         NA
# a1SD                    NA         NA         NA         NA
# a2SD                    NA         NA         NA         NA
# a3SD                    NA         NA         NA         NA
# a4SD                    NA         NA         NA         NA
# a1a2a3a4SD              NA         NA         NA         NA
# ySigma[1,1,1,1]         NA         NA         NA         NA
# ySigma[2,1,1,1]         NA         NA         NA         NA
# ySigma[1,2,1,1]         NA         NA         NA         NA
# ySigma[2,2,1,1]         NA         NA         NA         NA
# ySigma[1,1,2,1]         NA         NA         NA         NA
# ySigma[2,1,2,1]         NA         NA         NA         NA
# ySigma[1,2,2,1]         NA         NA         NA         NA
# ySigma[2,2,2,1]         NA         NA         NA         NA
# ySigma[1,1,3,1]         NA         NA         NA         NA
# ySigma[2,1,3,1]         NA         NA         NA         NA
# ySigma[1,2,3,1]         NA         NA         NA         NA
# ySigma[2,2,3,1]         NA         NA         NA         NA
# ySigma[1,1,1,2]         NA         NA         NA         NA
# ySigma[2,1,1,2]         NA         NA         NA         NA
# ySigma[1,2,1,2]         NA         NA         NA         NA
# ySigma[2,2,1,2]         NA         NA         NA         NA
# ySigma[1,1,2,2]         NA         NA         NA         NA
# ySigma[2,1,2,2]         NA         NA         NA         NA
# ySigma[1,2,2,2]         NA         NA         NA         NA
# ySigma[2,2,2,2]         NA         NA         NA         NA
# ySigma[1,1,3,2]         NA         NA         NA         NA
# ySigma[2,1,3,2]         NA         NA         NA         NA
# ySigma[1,2,3,2]         NA         NA         NA         NA
# ySigma[2,2,3,2]         NA         NA         NA         NA
# ySigma[1,1,1,3]         NA         NA         NA         NA
# ySigma[2,1,1,3]         NA         NA         NA         NA
# ySigma[1,2,1,3]         NA         NA         NA         NA
# ySigma[2,2,1,3]         NA         NA         NA         NA
# ySigma[1,1,2,3]         NA         NA         NA         NA
# ySigma[2,1,2,3]         NA         NA         NA         NA
# ySigma[1,2,2,3]         NA         NA         NA         NA
# ySigma[2,2,2,3]         NA         NA         NA         NA
# ySigma[1,1,3,3]         NA         NA         NA         NA
# ySigma[2,1,3,3]         NA         NA         NA         NA
# ySigma[1,2,3,3]         NA         NA         NA         NA
# ySigma[2,2,3,3]         NA         NA         NA         NA
# ySigma[1,1,1,4]         NA         NA         NA         NA
# ySigma[2,1,1,4]         NA         NA         NA         NA
# ySigma[1,2,1,4]         NA         NA         NA         NA
# ySigma[2,2,1,4]         NA         NA         NA         NA
# ySigma[1,1,2,4]         NA         NA         NA         NA
# ySigma[2,1,2,4]         NA         NA         NA         NA
# ySigma[1,2,2,4]         NA         NA         NA         NA
# ySigma[2,2,2,4]         NA         NA         NA         NA
# ySigma[1,1,3,4]         NA         NA         NA         NA
# ySigma[2,1,3,4]         NA         NA         NA         NA
# ySigma[1,2,3,4]         NA         NA         NA         NA
# ySigma[2,2,3,4]         NA         NA         NA         NA
# sigmaMode               NA         NA         NA         NA
# sigmaSD                 NA         NA         NA         NA
# nu                      NA         NA         NA         NA
#   [1] "b0"                "b1[1]"             "b1[2]"
#   [4] "b2[1]"             "b2[2]"             "b3[1]"
#   [7] "b3[2]"             "b3[3]"             "b4[1]"
#  [10] "b4[2]"             "b4[3]"             "b4[4]"
#  [13] "b1b2b3b4[1,1,1,1]" "b1b2b3b4[2,1,1,1]" "b1b2b3b4[1,2,1,1]"
#  [16] "b1b2b3b4[2,2,1,1]" "b1b2b3b4[1,1,2,1]" "b1b2b3b4[2,1,2,1]"
#  [19] "b1b2b3b4[1,2,2,1]" "b1b2b3b4[2,2,2,1]" "b1b2b3b4[1,1,3,1]"
#  [22] "b1b2b3b4[2,1,3,1]" "b1b2b3b4[1,2,3,1]" "b1b2b3b4[2,2,3,1]"
#  [25] "b1b2b3b4[1,1,1,2]" "b1b2b3b4[2,1,1,2]" "b1b2b3b4[1,2,1,2]"
#  [28] "b1b2b3b4[2,2,1,2]" "b1b2b3b4[1,1,2,2]" "b1b2b3b4[2,1,2,2]"
#  [31] "b1b2b3b4[1,2,2,2]" "b1b2b3b4[2,2,2,2]" "b1b2b3b4[1,1,3,2]"
#  [34] "b1b2b3b4[2,1,3,2]" "b1b2b3b4[1,2,3,2]" "b1b2b3b4[2,2,3,2]"
#  [37] "b1b2b3b4[1,1,1,3]" "b1b2b3b4[2,1,1,3]" "b1b2b3b4[1,2,1,3]"
#  [40] "b1b2b3b4[2,2,1,3]" "b1b2b3b4[1,1,2,3]" "b1b2b3b4[2,1,2,3]"
#  [43] "b1b2b3b4[1,2,2,3]" "b1b2b3b4[2,2,2,3]" "b1b2b3b4[1,1,3,3]"
#  [46] "b1b2b3b4[2,1,3,3]" "b1b2b3b4[1,2,3,3]" "b1b2b3b4[2,2,3,3]"
#  [49] "b1b2b3b4[1,1,1,4]" "b1b2b3b4[2,1,1,4]" "b1b2b3b4[1,2,1,4]"
#  [52] "b1b2b3b4[2,2,1,4]" "b1b2b3b4[1,1,2,4]" "b1b2b3b4[2,1,2,4]"
#  [55] "b1b2b3b4[1,2,2,4]" "b1b2b3b4[2,2,2,4]" "b1b2b3b4[1,1,3,4]"
#  [58] "b1b2b3b4[2,1,3,4]" "b1b2b3b4[1,2,3,4]" "b1b2b3b4[2,2,3,4]"
#  [61] "m[1,1,1,1]"        "m[2,1,1,1]"        "m[1,2,1,1]"
#  [64] "m[2,2,1,1]"        "m[1,1,2,1]"        "m[2,1,2,1]"
#  [67] "m[1,2,2,1]"        "m[2,2,2,1]"        "m[1,1,3,1]"
#  [70] "m[2,1,3,1]"        "m[1,2,3,1]"        "m[2,2,3,1]"
#  [73] "m[1,1,1,2]"        "m[2,1,1,2]"        "m[1,2,1,2]"
#  [76] "m[2,2,1,2]"        "m[1,1,2,2]"        "m[2,1,2,2]"
#  [79] "m[1,2,2,2]"        "m[2,2,2,2]"        "m[1,1,3,2]"
#  [82] "m[2,1,3,2]"        "m[1,2,3,2]"        "m[2,2,3,2]"
#  [85] "m[1,1,1,3]"        "m[2,1,1,3]"        "m[1,2,1,3]"
#  [88] "m[2,2,1,3]"        "m[1,1,2,3]"        "m[2,1,2,3]"
#  [91] "m[1,2,2,3]"        "m[2,2,2,3]"        "m[1,1,3,3]"
#  [94] "m[2,1,3,3]"        "m[1,2,3,3]"        "m[2,2,3,3]"
#  [97] "m[1,1,1,4]"        "m[2,1,1,4]"        "m[1,2,1,4]"
# [100] "m[2,2,1,4]"        "m[1,1,2,4]"        "m[2,1,2,4]"
# [103] "m[1,2,2,4]"        "m[2,2,2,4]"        "m[1,1,3,4]"
# [106] "m[2,1,3,4]"        "m[1,2,3,4]"        "m[2,2,3,4]"
# [109] "a1SD"              "a2SD"              "a3SD"
# [112] "a4SD"              "a1a2a3a4SD"        "ySigma[1,1,1,1]"
# [115] "ySigma[2,1,1,1]"   "ySigma[1,2,1,1]"   "ySigma[2,2,1,1]"
# [118] "ySigma[1,1,2,1]"   "ySigma[2,1,2,1]"   "ySigma[1,2,2,1]"
# [121] "ySigma[2,2,2,1]"   "ySigma[1,1,3,1]"   "ySigma[2,1,3,1]"
# [124] "ySigma[1,2,3,1]"   "ySigma[2,2,3,1]"   "ySigma[1,1,1,2]"
# [127] "ySigma[2,1,1,2]"   "ySigma[1,2,1,2]"   "ySigma[2,2,1,2]"
# [130] "ySigma[1,1,2,2]"   "ySigma[2,1,2,2]"   "ySigma[1,2,2,2]"
# [133] "ySigma[2,2,2,2]"   "ySigma[1,1,3,2]"   "ySigma[2,1,3,2]"
# [136] "ySigma[1,2,3,2]"   "ySigma[2,2,3,2]"   "ySigma[1,1,1,3]"
# [139] "ySigma[2,1,1,3]"   "ySigma[1,2,1,3]"   "ySigma[2,2,1,3]"
# [142] "ySigma[1,1,2,3]"   "ySigma[2,1,2,3]"   "ySigma[1,2,2,3]"
# [145] "ySigma[2,2,2,3]"   "ySigma[1,1,3,3]"   "ySigma[2,1,3,3]"
# [148] "ySigma[1,2,3,3]"   "ySigma[2,2,3,3]"   "ySigma[1,1,1,4]"
# [151] "ySigma[2,1,1,4]"   "ySigma[1,2,1,4]"   "ySigma[2,2,1,4]"
# [154] "ySigma[1,1,2,4]"   "ySigma[2,1,2,4]"   "ySigma[1,2,2,4]"
# [157] "ySigma[2,2,2,4]"   "ySigma[1,1,3,4]"   "ySigma[2,1,3,4]"
# [160] "ySigma[1,2,3,4]"   "ySigma[2,2,3,4]"   "sigmaMode"
# [163] "sigmaSD"           "nu"
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""

# %% [markdown]
# #### 4.2.2). Posteriori distribution

# %%
plotMCMC( mcmcCoda_All , datFrm=df , yName=yName , spatialPattern = "Gridded", targetLocation = "Center", x1Name=x4Name , x2Name=x3Name)
# Out:
# Plot with title "Data with Post. Pred."
# Plot with title "Data with Post. Pred."
# Plot with title "Data with Post. Pred."
# Plot with title "SD of Cell Sigma's"

# %% [markdown]
# ### 4.3). Plot contrast

# %% [markdown]
# #### 4.3.1). Main contrasts

# %% [markdown]
# ##### Feature

# %%
timeLogNumericOutput = calcAndPlotContrasts(mcmcCoda_All,df,x3Name,"b3")
str(timeLogNumericOutput)
# Out:
#  chr [1:3] "Hue" "Length" "Shape"
# [1] "Hue - Length probVar1Larger: 0"
# Plot with title "Hue - Length"
# [1] "Hue - Shape probVar1Larger: 0"
# Plot with title "Hue - Shape"
# [1] "Length - Shape probVar1Larger: 0"
# List of 3
#  $ Hue   :List of 2
#   ..$ Length:List of 1
#   .. ..$ probVar1Larger: num 0
#   ..$ Shape :List of 1
#   .. ..$ probVar1Larger: num 0
#  $ Length:List of 1
#   ..$ Shape:List of 1
#   .. ..$ probVar1Larger: num 0
#  $ Shape : list()
# Plot with title "Length - Shape"

# %% [markdown]
# ##### Element Number

# %%
timeLogNumericOutput = calcAndPlotContrasts(mcmcCoda_All,df,x4Name,"b4")
str(timeLogNumericOutput)
# Out:
#  chr [1:4] "12" "48" "192" "768"
# [1] "12 - 48 probVar1Larger: 0"
# Plot with title "12 - 48"
# [1] "12 - 192 probVar1Larger: 0"
# Plot with title "12 - 192"
# [1] "12 - 768 probVar1Larger: 0"
# Plot with title "12 - 768"
# [1] "48 - 192 probVar1Larger: 0"
# Plot with title "48 - 192"
# [1] "48 - 768 probVar1Larger: 0"
# Plot with title "48 - 768"
# [1] "192 - 768 probVar1Larger: 0"
# List of 4
#  $ 12 :List of 3
#   ..$ 48 :List of 1
#   .. ..$ probVar1Larger: num 0
#   ..$ 192:List of 1
#   .. ..$ probVar1Larger: num 0
#   ..$ 768:List of 1
#   .. ..$ probVar1Larger: num 0
#  $ 48 :List of 2
#   ..$ 192:List of 1
#   .. ..$ probVar1Larger: num 0
#   ..$ 768:List of 1
#   .. ..$ probVar1Larger: num 0
#  $ 192:List of 1
#   ..$ 768:List of 1
#   .. ..$ probVar1Larger: num 0
#  $ 768: list()
# Plot with title "192 - 768"

# %% [markdown]
# ##### Spatial Pattern

# %%
timeLogNumericOutput = calcAndPlotContrasts(mcmcCoda_All,df,x1Name)
str(timeLogNumericOutput)
# Out:
#  chr [1:2] "Gridded" "Random"
# [1] "Gridded - Random probVar1Larger: 0"
# List of 2
#  $ Gridded:List of 1
#   ..$ Random:List of 1
#   .. ..$ probVar1Larger: num 0
#  $ Random : list()
# Plot with title "Gridded - Random"

# %% [markdown]
# ##### Target Location

# %%
timeLogNumericOutput = calcAndPlotContrasts(mcmcCoda_All,df,x2Name, "b2")
str(timeLogNumericOutput)
# Out:
#  chr [1:2] "Center" "Periphery"
# [1] "Center - Periphery probVar1Larger: 0"
# List of 2
#  $ Center   :List of 1
#   ..$ Periphery:List of 1
#   .. ..$ probVar1Larger: num 0
#  $ Periphery: list()
# Plot with title "Center - Periphery"

# %%
geneWeightMat = function(X1 = NULL,X2 = NULL,X3 = NULL,X4 = NULL, val = 1)
{
    # separatorNum = 48 # 48 is the total num of all combinations: 2*2*3*4
    # if (is.null(X1)) separatorNum = separatorNum / length( spatialPatterns )
    # if (is.null(X2)) separatorNum = separatorNum / length( centerOrPeriph )
    # if (is.null(X3)) separatorNum = separatorNum / length( features )
    # if (is.null(X4)) separatorNum = separatorNum / length( elementNums )
    contrastCoef <- matrix(nrow = 0, ncol = 1) 
    for ( j4 in 1:length( elementNums ) ) # X1
        {
        m4 = is.null(X4)  || X4 == elementNums[j4]
        for ( j3 in 1:length( features ) )
            {
            m3 = is.null(X3) || X3 == features[j3]
            for ( j2 in 1:length( centerOrPeriph ) )
                {
                m2 = is.null(X2) || X2 == centerOrPeriph[j2]
                for ( j1 in 1:length( spatialPatterns ) )
                    {
                    m1 = is.null(X1)  || X1 == spatialPatterns[j1]
                    if (m1&&m2&&m3&&m4)
                        {
                        contrastCoef <- rbind(contrastCoef, c(val))
                        }
                    else
                        contrastCoef <- rbind(contrastCoef, 0)
                    }
                }
            }
        }
    return (contrastCoef)
}

plotContrast = function(comVal1=c("12", "48"), comVal2 = c("Shape", "Length"), mark = -0.25, mcmcCoda = mcmcCoda_All, ROPE= c(-1000,1000), caption = NULL)
{
    # (length48 - length12) - (shape48 - shape12) = length48 - length12 -shape48 + shape12
    contrastCoef <- matrix( 0, nrow = 48, ncol = 1) 
    for (val1 in comVal1)
        {
        if(length(comVal2)%%2 ==0)mark =-mark
        for (val2 in comVal2)
            {
            ans = geneWeightMat(X3 = val2, X4 = val1, val = mark)
            contrastCoef = contrastCoef + ans
            mark = -mark
            }
        }
    #print(contrastCoef)
    mcmcMat = as.matrix(mcmcCoda,chains=TRUE)
    RTMat = 10^mcmcMat[,substr(colnames(mcmcMat),1,2)=="m["] # back transform to real RT, in ms
    postContrast = (RTMat%*% contrastCoef )
    if (is.null(caption))
        caption = paste0(comVal1[2],"-", comVal1[1], " \n(x)\n", comVal2[2]," .VS. ", comVal2[1])
    if (length(comVal2) >= 2 )
        xlabChar = "Difference of Differences (ms)"
    else
        xlabChar = "Difference (ms)"
    compInfo = plotPost( postContrast , xlab=xlabChar ,main= caption,ROPE= ROPE)
    #show(compInfo)
}

# %% [markdown]
# #### 4.3.2).  Simple effect contrasts

# %% [markdown]
# ##### How change of element number affect RT for Hue

# %%
Mainfeature = "Hue"
for (i in 1:(length(elementNums)-1))
{
    Val1 = elementNums[i]
    Val2 = elementNums[i+1]
    plotContrast(comVal1 = c(Val1,Val2), comVal2 = c(Mainfeature), 
                 mark = -0.25,ROPE= c(-100,1000), 
                 caption = paste0(Val2, " - ", Val1, " at ",Mainfeature))
}
# Out:
# Plot with title "48 - 12 at Hue"
# Plot with title "192 - 48 at Hue"
# Plot with title "768 - 192 at Hue"

# %% [markdown]
# ##### How change of element number affect RT for Length

# %%
Mainfeature = "Length"
for (i in 1:(length(elementNums)-1))
{
    Val1 = elementNums[i]
    Val2 = elementNums[i+1]
    plotContrast(comVal1 = c(Val1,Val2), comVal2 = c(Mainfeature), 
                 mark = -0.25,ROPE= c(-100,1000), 
                 caption = paste0(Val2, " - ", Val1, " at ",Mainfeature))
}
# Out:
# Plot with title "48 - 12 at Length"
# Plot with title "192 - 48 at Length"
# Plot with title "768 - 192 at Length"

# %% [markdown]
# ##### How change of element number affect RT for Shape

# %%
Mainfeature = "Shape"
for (i in 1:(length(elementNums)-1))
{
    Val1 = elementNums[i]
    Val2 = elementNums[i+1]
    plotContrast(comVal1 = c(Val1,Val2), comVal2 = c(Mainfeature), 
                 mark = -0.25,ROPE= c(-100,1000), 
                 caption = paste0(Val2, " - ", Val1, " at ",Mainfeature))
}
# Out:
# Plot with title "48 - 12 at Shape"
# Plot with title "192 - 48 at Shape"
# Plot with title "768 - 192 at Shape"

# %% [markdown]
# #### 4.3.3).  Interaction effect contrasts

# %% [markdown]
# ##### How change of element number affect RT differently between features

# %%
for (i in 1:(length(elementNums)-1))
    for (j in 1:(length(features)-1))
    {
        comVal1 = c(elementNums[i],elementNums[i+1])
        comVal2 = c(features[j],features[j+1])
        plotContrast(comVal1 = comVal1, comVal2 = comVal2, 
                     mark = -0.25,ROPE= c(-100,1000))
    }
# Out:
# Plot with title "48-12
# (x)
# Length .VS. Hue"
# Plot with title "48-12
# (x)
# Shape .VS. Length"
# Plot with title "192-48
# (x)
# Length .VS. Hue"
# Plot with title "192-48
# (x)
# Shape .VS. Length"
# Plot with title "768-192
# (x)
# Length .VS. Hue"
# Plot with title "768-192
# (x)
# Shape .VS. Length"

# %% [markdown]
# ##### How spatial pattern affect the impact on RT of element number, for HUE, LENGTH, and SHAPE

# %%
for (feat in features)
    for (i in 1:(length(elementNums)-1))
        for (j in 1:(length(spatialPatterns)-1))
        {
            mark = -0.25
            comVal1 = c(elementNums[i],elementNums[i+1])
            comVal2 = c(spatialPatterns[j],spatialPatterns[j+1])
            contrastCoef <- matrix( 0, nrow = 48, ncol = 1) 
            for (val1 in comVal1)
                {mark =-mark
                for (val2 in comVal2)
                    {
                    ans = geneWeightMat(X1 = val2,X3 = feat, X4 = val1, val = mark)
                    contrastCoef = contrastCoef + ans
                    mark = -mark
                    }
                }
            #print(contrastCoef)
            mcmcMat = as.matrix(mcmcCoda_All,chains=TRUE)
            RTMat = 10^mcmcMat[,substr(colnames(mcmcMat),1,2)=="m["] # back transform to real RT, in ms
            postContrast = RTMat%*% contrastCoef 
            caption = paste0(comVal1[2],"-", comVal1[1], " \n(x)\n", comVal2[2]," .VS. ", comVal2[1])
            xlabChar = paste0(feat, " - Difference of Differences (ms)")
            compInfo = plotPost( postContrast , xlab=xlabChar ,main= caption,ROPE= c(-100,1000))
        }
# Out:
# Plot with title "48-12
# (x)
# Random .VS. Gridded"
# Plot with title "192-48
# (x)
# Random .VS. Gridded"
# Plot with title "768-192
# (x)
# Random .VS. Gridded"
# Plot with title "48-12
# (x)
# Random .VS. Gridded"
# Plot with title "192-48
# (x)
# Random .VS. Gridded"
# Plot with title "768-192
# (x)
# Random .VS. Gridded"
# Plot with title "48-12
# (x)
# Random .VS. Gridded"
# Plot with title "192-48
# (x)
# Random .VS. Gridded"
# Plot with title "768-192
# (x)
# Random .VS. Gridded"

# %% [markdown]
# ##### How target location affect the impact on RT of element number, for HUE, LENGTH, and SHAPE

# %%
for (feat in features)
    for (i in 1:(length(elementNums)-1))
        for (j in 1:(length(centerOrPeriph)-1))
        {
            mark = -0.25
            comVal1 = c(elementNums[i],elementNums[i+1])
            comVal2 = c(centerOrPeriph[j],centerOrPeriph[j+1])
            contrastCoef <- matrix( 0, nrow = 48, ncol = 1) 
            for (val1 in comVal1)
                {mark =-mark
                for (val2 in comVal2)
                    {
                    ans = geneWeightMat(X2 = val2,X3 = feat, X4 = val1, val = mark)
                    contrastCoef = contrastCoef + ans
                    mark = -mark
                    }
                }
            #print(contrastCoef)
            mcmcMat = as.matrix(mcmcCoda_All,chains=TRUE)
            RTMat = 10^mcmcMat[,substr(colnames(mcmcMat),1,2)=="m["] # back transform to real RT, in ms
            postContrast = RTMat%*% contrastCoef 
            caption = paste0(comVal1[2],"-", comVal1[1], " \n(x)\n", comVal2[2]," .VS. ", comVal2[1])
            xlabChar = paste0(feat, " - Difference of Differences (ms)")
            compInfo = plotPost( postContrast , xlab=xlabChar ,main= caption,ROPE= c(-100,1000))
        }
# Out:
# Plot with title "48-12
# (x)
# Periphery .VS. Center"
# Plot with title "192-48
# (x)
# Periphery .VS. Center"
# Plot with title "768-192
# (x)
# Periphery .VS. Center"
# Plot with title "48-12
# (x)
# Periphery .VS. Center"
# Plot with title "192-48
# (x)
# Periphery .VS. Center"
# Plot with title "768-192
# (x)
# Periphery .VS. Center"
# Plot with title "48-12
# (x)
# Periphery .VS. Center"
# Plot with title "192-48
# (x)
# Periphery .VS. Center"
# Plot with title "768-192
# (x)
# Periphery .VS. Center"

# %% [markdown]
# ### 4.4). Show analysis result in vis

# %% [markdown]
# #### 4.4.1). Auxiliary functions

# %%
getIntervals = function(mcmcCoda)
{
    relevantVarNames = list("12","48","192","768")
    
    # added factors
    datMat = as.matrix(mcmcCoda,chains=TRUE)   
    datFrame = data.frame(datMat)
    datFrame$c1 = datFrame$b0 + datFrame$b4.1. 
    datFrame$c2 = datFrame$b0 + datFrame$b4.2. 
    datFrame$c3 = datFrame$b0 + datFrame$b4.3. 
    datFrame$c4 = datFrame$b0 + datFrame$b4.4. 
    
    datFrameC = data.frame(datFrame[,c("c1","c2","c3","c4")])
    names(datFrameC) = relevantVarNames
    #timeLogFrameC
    
    q1 = quantile(datFrameC[["12"]],probs=c(0.025,0.5,0.975))
    q2 = quantile(datFrameC[["48"]],probs=c(0.025,0.5,0.975))
    q3 = quantile(datFrameC[["192"]],probs=c(0.025,0.5,0.975))
    q4 = quantile(datFrameC[["768"]],probs=c(0.025,0.5,0.975))
    
    
    low = c(q1[1],q2[1],q3[1],q4[1])
    mid = c(q1[2],q2[2],q3[2],q4[2])
    high = c(q1[3],q2[3],q3[3],q4[3])
    
    datIntervals = data.frame(keyfactor=unlist(relevantVarNames, use.names = FALSE),low=low,mid=mid,high=high)
    datIntervals$qlowl = lapply(datIntervals$low,FUN=invlogit)
    datIntervals$qmidl = lapply(datIntervals$mid,FUN=invlogit)
    datIntervals$qhighl = lapply(datIntervals$high,FUN=invlogit)
    return (datIntervals)
}

# plot
plotAnaResults = function(datIntervals)
{
    chartHueLogit = ggplot() +
      #geom_violin(data=dfa,linetype="blank",bw=0.05,aes(x=factor(Condition),y=hue,fill=Condition)) +
      scale_fill_manual(values=c("#fbb4ae", "#b3cde3", "#ccebc5","#decbe4")) + 
      theme(panel.background = element_rect(fill = "#F6F6F6", colour = "#F6F6F6", size = 0, linetype = "solid"),
            legend.position = "none",axis.title.x = element_blank(),
            axis.text=element_text(size=14),axis.title.y=element_text(size=14)) +
      ylab("Theta (Prob. of hue Trial)") +
      #coord_cartesian(ylim = c(0, 10)) + 
      # coord_fixed(ratio = 500000000000,ylim=c(0.99999999999,1)) +
      geom_point(data=datIntervals,aes(x=factor(keyfactor, levels = c("12", "48", "192", "768"), ordered = TRUE),y=invlogit(mid)))+
      geom_errorbar(data=datIntervals,aes(x=factor(keyfactor, levels = c("12", "48", "192", "768"),ordered = TRUE),ymin=invlogit(low), ymax=invlogit(high)), width=.3)  +
      geom_text(data=datIntervals,size=5,aes(x=factor(keyfactor, levels = c("12", "48", "192", "768"),ordered = TRUE),y=0.95, label=paste(format(invlogit(mid)*100, digits = 4),"%",sep="")))
    
    plot(chartHueLogit)
    
    # plot
    charthue = ggplot() +
      # geom_violin(data=dfa,linetype="blank",bw=0.05,aes(x=factor(Condition),y=hue,fill=Condition)) +
      scale_fill_manual(values=c("#fbb4ae", "#b3cde3", "#ccebc5","#decbe4")) + 
      theme(panel.background = element_rect(fill = "#F6F6F6", colour = "#F6F6F6", size = 0, linetype = "solid"),
            legend.position = "none",axis.title.x = element_blank(),
            axis.text=element_text(size=14),axis.title.y=element_text(size=14)) +
      ylab("Theta (Prob. of hue Trial)") +
      #coord_cartesian(ylim = c(0, 10)) + 
      #coord_fixed(ratio = 0.1,ylim=c(0,50)) +
      geom_point(data=datIntervals,aes(x=factor(keyfactor, levels = c("12", "48", "192", "768"), ordered = TRUE),y=mid))+
      geom_errorbar(data=datIntervals,aes(x=factor(keyfactor, levels = c("12", "48", "192", "768"), ordered = TRUE),ymin=low, ymax=high), width=.3)  +
      geom_text(data=datIntervals,size=5,aes(x=factor(keyfactor, levels = c("12", "48", "192", "768"), ordered = TRUE),y=0.95, label=paste(format(10**mid, digits = 4),"ms",sep="")))
    
    plot(charthue)
    
    # postFileName = paste(resultsGraphicsDir,"vertical-graph-hue.pdf",sep="")
    #     pdf(postFileName,width=6,height=4)
    #     plot(charthue)
    #     dev.off()
}

# %% [markdown]
# #### 4.4.2).  Plot of element number

# %%
plotAnaResults(getIntervals(mcmcCoda_All))
# Out:
# Warning message:
# "The `size` argument of `element_rect()` is deprecated as of ggplot2 3.4.0.
# i Please use the `linewidth` argument instead."
# plot without title
# plot without title
